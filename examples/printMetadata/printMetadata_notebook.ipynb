# %%
import sys
import os

print("python path", sys.executable)
print("python version", sys.version)

richrdf_path = os.path.abspath(os.path.join(os.getcwd(), '../..'))
sys.path.append(richrdf_path)

try:
    import ROOT
except ImportError:
    import richrdf.experimental.setupROOT
    cvmfsversion="2024-10-03/x86_64-almalinux9-gcc14.2.0-opt"
    print(f"\nNo ROOT can be imported, trying to set up ROOT from cvmfs {cvmfsversion}\n")
    try:
        import richrdf.experimental
        richrdf.experimental.setupROOT.setupROOT(cvmfsversion=cvmfsversion)
        import ROOT
        print("\nROOT from cvmfs loaded\n")
    except ImportError:
        print("\nROOT not found, please set up ROOT\n")

import richrdf
print(richrdf.get_include_path())
# Out:
# python path /home/llr/ilc/liang/data/liang/software/anaconda3/envs/anaedm/bin/python
# python version 3.11.13 | packaged by conda-forge | (main, Jun  4 2025, 14:48:23) [GCC 13.3.0]
#
# No ROOT can be imported, trying to set up ROOT from cvmfs 2024-10-03/x86_64-almalinux9-gcc14.2.0-opt
#
# CVMFS version 2024-10-03/x86_64-almalinux9-gcc14.2.0-opt
# LDDIR  ['/cvmfs/sw.hsf.org/key4hep/releases/2024-10-03/x86_64-almalinux9-gcc14.2.0-opt/root/6.32.04-vms5ij/lib', '/cvmfs/sw.hsf.org/key4hep/releases/2024-10-03/x86_64-almalinux9-gcc14.2.0-opt/edm4hep/0.99.1-zincmm/lib', '/cvmfs/sw.hsf.org/key4hep/releases/2024-10-03/x86_64-almalinux9-gcc14.2.0-opt/podio/1.1-ur2cnz/lib']
# ROOTDIR ['/cvmfs/sw.hsf.org/key4hep/releases/2024-10-03/x86_64-almalinux9-gcc14.2.0-opt/root/6.32.04-vms5ij/lib'] ['/cvmfs/sw.hsf.org/key4hep/releases/2024-10-03/x86_64-almalinux9-gcc14.2.0-opt/root/6.32.04-vms5ij/lib/root']
# Includes ['/cvmfs/sw.hsf.org/key4hep/releases/2024-10-03/x86_64-almalinux9-gcc14.2.0-opt/edm4hep/0.99.1-zincmm/include', '/cvmfs/sw.hsf.org/key4hep/releases/2024-10-03/x86_64-almalinux9-gcc14.2.0-opt/podio/1.1-ur2cnz/include']
#
# ROOT from cvmfs loaded
#
# /grid_mnt/vol_home/llr/ilc/liang/projects/pi0reco/thirdparty/richrdf/richrdf/cpp_include

# %%
if not os.path.exists("zh_mumu_REC.edm4hep.root"):
    # Download the sample file
    import urllib.request
    url = "https://raw.githubusercontent.com/lhprojects/edm4hep_sample/refs/heads/main/ILD/zh_mumu_REC.edm4hep.root"
    urllib.request.urlretrieve(url, "zh_mumu_REC.edm4hep.root")

# %%
import richrdf
ROOT.gInterpreter.AddIncludePath(richrdf.get_include_path())

# %%
filename = "zh_mumu_REC.edm4hep.root"
df = richrdf.RichRDF("events", filename)

podio_metadata = df.getMetadata().podio_metadata
print(podio_metadata.getCollTypeInfos())
for collName in podio_metadata.getCollNames():
    try:
        collID = podio_metadata.getCollIDByName(collName)
        collType = podio_metadata.getCollTypeByID(collID)
        print(f"{collName:<40} {collID:<15} {collType.name}")
        
    except ValueError as e:
        print(f"Error retrieving collection {collName} ID {collID}")
# Out:
# [(4142649571, 'edm4hep::CalorimeterHitCollection', 0, 2), (3264783176, 'edm4hep::SimCalorimeterHitCollection', 0, 2), (2713111240, 'edm4hep::CaloHitContributionCollection', 0, 2), (1262281506, 'edm4hep::VertexCollection', 0, 2), (2005909249, 'edm4hep::VertexRecoParticleLinkCollection', 0, 2), (3251527872, 'edm4hep::ReconstructedParticleCollection', 0, 2), (3028409779, 'edm4hep::VertexRecoParticleLinkCollection', 0, 2), (2006195126, 'edm4hep::VertexCollection', 0, 2), (4280388300, 'edm4hep::VertexRecoParticleLinkCollection', 0, 2), (1468310369, 'edm4hep::ReconstructedParticleCollection', 0, 2), (3414032665, 'edm4hep::VertexRecoParticleLinkCollection', 0, 2), (642585747, 'edm4hep::TrackCollection', 0, 2), (1523323146, 'edm4hep::RecDqdxCollection', 0, 2), (3356451924, 'edm4hep::TrackCollection', 0, 2), (2718534675, 'edm4hep::RecDqdxCollection', 0, 2), (3799154064, 'edm4hep::ClusterMCParticleLinkCollection', 0, 2), (3755793839, 'edm4hep::ReconstructedParticleCollection', 1, 2), (1659998992, 'edm4hep::SimCalorimeterHitCollection', 1, 2), (934154155, 'edm4hep::CalorimeterHitCollection', 0, 2), (184706034, 'edm4hep::CalorimeterHitCollection', 0, 2), (679272617, 'edm4hep::CalorimeterHitCollection', 0, 2), (2639401739, 'edm4hep::CaloHitSimCaloHitLinkCollection', 0, 2), (3746919593, 'edm4hep::CaloHitSimCaloHitLinkCollection', 0, 2), (3369083523, 'edm4hep::CaloHitContributionCollection', 0, 2), (730710384, 'edm4hep::CaloHitContributionCollection', 0, 2), (1125540746, 'edm4hep::SimCalorimeterHitCollection', 0, 2), (2062546891, 'edm4hep::CaloHitContributionCollection', 0, 2), (2663173212, 'edm4hep::SimCalorimeterHitCollection', 0, 2), (3698582911, 'edm4hep::CaloHitContributionCollection', 0, 2), (3455162466, 'edm4hep::SimCalorimeterHitCollection', 0, 2), (2817286281, 'edm4hep::CaloHitContributionCollection', 0, 2), (2973946332, 'edm4hep::CalorimeterHitCollection', 0, 2), (3806880926, 'edm4hep::CalorimeterHitCollection', 0, 2), (2480939121, 'edm4hep::CaloHitSimCaloHitLinkCollection', 0, 2), (1930145151, 'edm4hep::CaloHitSimCaloHitLinkCollection', 0, 2), (1708620450, 'edm4hep::CaloHitContributionCollection', 0, 2), (2601469492, 'edm4hep::CaloHitContributionCollection', 0, 2), (3604114720, 'edm4hep::SimCalorimeterHitCollection', 1, 2), (1597524370, 'edm4hep::CalorimeterHitCollection', 0, 2), (3600902160, 'edm4hep::CalorimeterHitCollection', 0, 2), (75879906, 'edm4hep::CalorimeterHitCollection', 0, 2), (1122876349, 'edm4hep::SimCalorimeterHitCollection', 0, 2), (2616675594, 'edm4hep::CaloHitContributionCollection', 0, 2), (473515324, 'edm4hep::SimCalorimeterHitCollection', 0, 2), (2651639688, 'edm4hep::CaloHitContributionCollection', 0, 2), (2989754106, 'edm4hep::CaloHitSimCaloHitLinkCollection', 0, 2), (439590450, 'edm4hep::CaloHitSimCaloHitLinkCollection', 0, 2), (3616779153, 'edm4hep::EventHeaderCollection', 0, 2), (3085321845, 'edm4hep::TrackCollection', 0, 2), (3504007703, 'edm4hep::RecDqdxCollection', 0, 2), (906304559, 'edm4hep::SimTrackerHitCollection', 1, 2), (2443879081, 'edm4hep::SimTrackerHitCollection', 1, 2), (1890391908, 'edm4hep::SimTrackerHitCollection', 0, 2), (2431389277, 'edm4hep::TrackerHitSimTrackerHitLinkCollection', 0, 2), (2216447081, 'edm4hep::TrackerHitPlaneCollection', 0, 2), (249458290, 'edm4hep::TrackerHitSimTrackerHitLinkCollection', 0, 2), (4066498571, 'edm4hep::TrackerHit3DCollection', 0, 2), (2269001718, 'edm4hep::TrackerHitSimTrackerHitLinkCollection', 0, 2), (1573076897, 'edm4hep::TrackerHitPlaneCollection', 0, 2), (3828367965, 'edm4hep::ReconstructedParticleCollection', 0, 2), (2847326644, 'edm4hep::VertexRecoParticleLinkCollection', 0, 2), (2102811976, 'edm4hep::ReconstructedParticleCollection', 0, 2), (285672278, 'edm4hep::VertexRecoParticleLinkCollection', 0, 2), (3935524627, 'edm4hep::ReconstructedParticleCollection', 0, 2), (1809191767, 'edm4hep::VertexRecoParticleLinkCollection', 0, 2), (3547015460, 'edm4hep::ReconstructedParticleCollection', 1, 2), (1136010528, 'edm4hep::CalorimeterHitCollection', 0, ...
# EventHeader                              3616779153      edm4hep::EventHeaderCollection
# MCParticles                              2714477136      edm4hep::MCParticleCollection
# FTDCollection                            1890391908      edm4hep::SimTrackerHitCollection
# SETCollection                            69654757        edm4hep::SimTrackerHitCollection
# SITCollection                            1030885172      edm4hep::SimTrackerHitCollection
# TPCCollection                            373938918       edm4hep::SimTrackerHitCollection
# TPCLowPtCollection                       3927140060      edm4hep::SimTrackerHitCollection
# TPCSpacePointCollection                  418780947       edm4hep::SimTrackerHitCollection
# VXDCollection                            1730162214      edm4hep::SimTrackerHitCollection
# BeamCalCollection                        3264783176      edm4hep::SimCalorimeterHitCollection
# BeamCalCollectionContributions           2713111240      edm4hep::CaloHitContributionCollection
# Error retrieving collection ECalBarrelScHitsEven ID 2476866799
# ECalBarrelScHitsEvenContributions        3369083523      edm4hep::CaloHitContributionCollection
# Error retrieving collection ECalBarrelScHitsOdd ID 716047749
# ECalBarrelScHitsOddContributions         730710384       edm4hep::CaloHitContributionCollection
# ECalBarrelSiHitsEven                     1125540746      edm4hep::SimCalorimeterHitCollection
# ECalBarrelSiHitsEvenContributions        2062546891      edm4hep::CaloHitContributionCollection
# ECalBarrelSiHitsOdd                      2663173212      edm4hep::SimCalorimeterHitCollection
# ECalBarrelSiHitsOddContributions         3698582911      edm4hep::CaloHitContributionCollection
# Error retrieving collection ECalEndcapScHitsEven ID 1776977724
# ECalEndcapScHitsEvenContributions        1708620450      edm4hep::CaloHitContributionCollection
# Error retrieving collection ECalEndcapScHitsOdd ID 987321220
# ECalEndcapScHitsOddContributions         2601469492      edm4hep::CaloHitContributionCollection
# ECalEndcapSiHitsEven                     1122876349      edm4hep::SimCalorimeterHitCollection
# ECalEndcapSiHitsEvenContributions        2616675594      edm4hep::CaloHitContributionCollection
# ECalEndcapSiHitsOdd                      473515324       edm4hep::SimCalorimeterHitCollection
# ECalEndcapSiHitsOddContributions         2651639688      edm4hep::CaloHitContributionCollection
# EcalEndcapRingCollection                 3455162466      edm4hep::SimCalorimeterHitCollection
# EcalEndcapRingCollectionContributions    2817286281      edm4hep::CaloHitContributionCollection
# Error retrieving collection HCalBarrelRPCHits ID 1224903058
# HCalBarrelRPCHitsContributions           1937055782      edm4hep::CaloHitContributionCollection
# Error retrieving collection HCalECRingRPCHits ID 1859929762
# HCalECRingRPCHitsContributions           4288302129      edm4hep::CaloHitContributionCollection
# Error retrieving collection HCalEndcapRPCHits ID 1765375950
# HCalEndcapRPCHitsContributions           226103412       edm4hep::CaloHitContributionCollection
# HcalBarrelRegCollection                  4238428472      edm4hep::SimCalorimeterHitCollection
# HcalBarrelRegCollectionContributions     532303217       edm4hep::CaloHitContributionCollection
# HcalEndcapRingCollection                 754442686       edm4hep::SimCalorimeterHitCollection
# HcalEndcapRingCollectionContributions    611655322       edm4hep::CaloHitContributionCollection
# HcalEndcapsCollection                    1287950358      edm4hep::SimCalorimeterHitCollection
# HcalEndcapsCollectionContributions       1550427246      edm4hep::CaloHitContributionCollection
# LHCalCollection                          4269684158      edm4hep::SimCalorimeterHitCollection
# LHCalCollectionContributions             4128413775      edm4hep::CaloHitContributionCollection
# LumiCalCollection                        1165332501      edm4hep::SimCalorimeterHitCollection
# LumiCalCollectionContributions           3669141454      edm4hep::CaloHitContributionCollection
# YokeBarrelCollection                     2545921446      edm4hep::SimCalorimeterHitCollection
# YokeBarrelCollectionContributions        1578098675      edm4hep::CaloHitContributionCollection
# YokeEndcapsCollection                    2226593345      edm4hep::SimCalorimeterHitCollection
# YokeEndcapsCollectionContributions       2527906421      edm4hep::CaloHitContributionCollection
# BCAL                                     4142649571      edm4hep::CalorimeterHitCollection
# BuildUpVertex                            1262281506      edm4hep::VertexCollection
# BuildUpVertex_associatedParticles        2005909249      edm4hep::VertexRecoParticleLinkCollection
# BuildUpVertex_RP                         3251527872      edm4hep::ReconstructedParticleCollection
# BuildUpVertex_RP_startVertices           3028409779      edm4hep::VertexRecoParticleLinkCollection
# BuildUpVertex_V0                         2006195126      edm4hep::VertexCollection
# BuildUpVertex_V0_associatedParticles     4280388300      edm4hep::VertexRecoParticleLinkCollection
# BuildUpVertex_V0_RP                      1468310369      edm4hep::ReconstructedParticleCollection
# BuildUpVertex_V0_RP_startVertices        3414032665      edm4hep::VertexRecoParticleLinkCollection
# ClupatraTrackSegments                    3356451924      edm4hep::TrackCollection
# ClupatraTrackSegments_dQdx               2718534675      edm4hep::RecDqdxCollection
# ClupatraTracks                           642585747       edm4hep::TrackCollection
# ClupatraTracks_dQdx                      1523323146      edm4hep::RecDqdxCollection
# EcalBarrelCollectionDigi                 934154155       edm4hep::CalorimeterHitCollection
# EcalBarrelCollectionGapHits              184706034       edm4hep::CalorimeterHitCollection
# EcalBarrelCollectionRec                  679272617       edm4hep::CalorimeterHitCollection
# EcalEndcapRingCollectionDigi             2973946332      edm4hep::CalorimeterHitCollection
# EcalEndcapRingCollectionRec              3806880926      edm4hep::CalorimeterHitCollection
# EcalEndcapsCollectionDigi                1597524370      edm4hep::CalorimeterHitCollection
# EcalEndcapsCollectionGapHits             3600902160      edm4hep::CalorimeterHitCollection
# EcalEndcapsCollectionRec                 75879906        edm4hep::CalorimeterHitCollection
# FTDPixelTrackerHits                      2216447081      edm4hep::TrackerHitPlaneCollection
# FTDSpacePoints                           4066498571      edm4hep::TrackerHit3DCollection
# FTDStripTrackerHits                      1573076897      edm4hep::TrackerHitPlaneCollection
# ForwardTracks                            3085321845      edm4hep::TrackCollection
# ForwardTracks_dQdx                       3504007703      edm4hep::RecDqdxCollection
# GammaGammaCandidateEtaPrimes             3828367965      edm4hep::ReconstructedParticleCollection
# GammaGammaCandidateEtaPrimes_startVertices 2847326644      edm4hep::VertexRecoParticleLinkCollection
# GammaGammaCandidateEtas                  2102811976      edm4hep::ReconstructedParticleCollection
# GammaGammaCandidateEtas_startVertices    285672278       edm4hep::VertexRecoParticleLinkCollection
# GammaGammaCandidatePi0s                  3935524627      edm4hep::ReconstructedParticleCollection
# GammaGammaCandidatePi0s_startVertices    1809191767      edm4hep::VertexRecoParticleLinkCollection
# HcalBarrelCollectionDigi                 1136010528      edm4hep::CalorimeterHitCollection
# HcalBarrelCollectionRec                  1573202488      edm4hep::CalorimeterHitCollection
# HcalEndcapRingCollectionDigi             3460926111      edm4hep::CalorimeterHitCollection
# HcalEndcapRingCollectionRec              696988188       edm4hep::CalorimeterHitCollection
# HcalEndcapsCollectionDigi                2279918714      edm4hep::CalorimeterHitCollection
# HcalEndcapsCollectionRec                 1452463960      edm4hep::CalorimeterHitCollection
# KinkRecoParticles                        3523138448      edm4hep::ReconstructedParticleCollection
# KinkRecoParticles_startVertices          3167941795      edm4hep::VertexRecoParticleLinkCollection
# KinkVertices                             1729448957      edm4hep::VertexCollection
# KinkVertices_associatedParticles         3351499524      edm4hep::VertexRecoParticleLinkCollection
# LCAL                                     541838354       edm4hep::CalorimeterHitCollection
# LHCAL                                    2194230057      edm4hep::CalorimeterHitCollection
# MUON                                     255155955       edm4hep::CalorimeterHitCollection
# MarlinTrkTracks                          1919347268      edm4hep::TrackCollection
# MarlinTrkTracks_dQdx                     507415505       edm4hep::RecDqdxCollection
# MarlinTrkTracksKaon                      2605392141      edm4hep::TrackCollection
# MarlinTrkTracksKaon_dQdx                 3209682281      edm4hep::RecDqdxCollection
# MarlinTrkTracksProton                    1278974530      edm4hep::TrackCollection
# MarlinTrkTracksProton_dQdx               3386192848      edm4hep::RecDqdxCollection
# PandoraClusters                          450524680       edm4hep::ClusterCollection
# PandoraPFANewStartVertices               2512145315      edm4hep::VertexCollection
# PandoraPFANewStartVertices_associatedParticles 353583779       edm4hep::VertexRecoParticleLinkCollection
# PandoraPFOs                              4196981182      edm4hep::ReconstructedParticleCollection
# PandoraPFOs_PID_BasicVariablePID         2630093478      edm4hep::ParticleIDCollection
# PandoraPFOs_PID_LowMomMuID               3223639309      edm4hep::ParticleIDCollection
# PandoraPFOs_PID_ShowerShapesPID          2648141424      edm4hep::ParticleIDCollection
# PandoraPFOs_PID_dEdxPID                  3895104132      edm4hep::ParticleIDCollection
# PandoraPFOs_PID_LikelihoodPID            3763681632      edm4hep::ParticleIDCollection
# PandoraPFOs_PID_TrackLengthProcessor     4027807991      edm4hep::ParticleIDCollection
# PandoraPFOs_PID_TOFEstimators0ps         3717208972      edm4hep::ParticleIDCollection
# PandoraPFOs_PID_TOFEstimators10ps        3017489191      edm4hep::ParticleIDCollection
# PandoraPFOs_PID_TOFEstimators50ps        2546477804      edm4hep::ParticleIDCollection
# PandoraPFOs_PID_TOFEstimators100ps       1912512370      edm4hep::ParticleIDCollection
# PandoraPFOs_startVertices                2271775733      edm4hep::VertexRecoParticleLinkCollection
# PrimaryVertex                            3533821269      edm4hep::VertexCollection
# PrimaryVertex_associatedParticles        1115494200      edm4hep::VertexRecoParticleLinkCollection
# PrimaryVertex_RP                         3367113833      edm4hep::ReconstructedParticleCollection
# PrimaryVertex_RP_startVertices           1759872424      edm4hep::VertexRecoParticleLinkCollection
# ProngRecoParticles                       4080577279      edm4hep::ReconstructedParticleCollection
# ProngRecoParticles_startVertices         4090137212      edm4hep::VertexRecoParticleLinkCollection
# ProngVertices                            3098489848      edm4hep::VertexCollection
# ProngVertices_associatedParticles        799506551       edm4hep::VertexRecoParticleLinkCollection
# SETSpacePoints                           2598406911      edm4hep::TrackerHit3DCollection
# SETTrackerHits                           466578544       edm4hep::TrackerHitPlaneCollection
# SITTrackerHits                           556258249       edm4hep::TrackerHitPlaneCollection
# SiTracks                                 2195150269      edm4hep::TrackCollection
# SiTracks_dQdx                            349086238       edm4hep::RecDqdxCollection
# SplitRecoParticles                       455588529       edm4hep::ReconstructedParticleCollection
# SplitRecoParticles_startVertices         3528353289      edm4hep::VertexRecoParticleLinkCollection
# SplitVertices                            1279110915      edm4hep::VertexCollection
# SplitVertices_associatedParticles        2544077298      edm4hep::VertexRecoParticleLinkCollection
# SubsetTracks                             3670138553      edm4hep::TrackCollection
# SubsetTracks_dQdx                        3569644825      edm4hep::RecDqdxCollection
# TPCTrackerHits                           2436154943      edm4hep::TrackerHit3DCollection
# V0RecoParticles                          2189147323      edm4hep::ReconstructedParticleCollection
# V0RecoParticles_startVertices            3351286710      edm4hep::VertexRecoParticleLinkCollection
# V0Vertices                               3886328759      edm4hep::VertexCollection
# V0Vertices_associatedParticles           1472930574      edm4hep::VertexRecoParticleLinkCollection
# VXDTrackerHits                           3678648449      edm4hep::TrackerHitPlaneCollection
# DistilledPFOs                            3755793839      edm4hep::ReconstructedParticleCollection
# EcalBarrelCollection                     1659998992      edm4hep::SimCalorimeterHitCollection
# EcalEndcapsCollection                    3604114720      edm4hep::SimCalorimeterHitCollection
# FTD_PIXELCollection                      906304559       edm4hep::SimTrackerHitCollection
# FTD_STRIPCollection                      2443879081      edm4hep::SimTrackerHitCollection
# GammaGammaParticles                      3547015460      edm4hep::ReconstructedParticleCollection
# MCParticlesSkimmed                       380785324       edm4hep::MCParticleCollection
# ClusterMCTruthLink                       3799154064      edm4hep::ClusterMCParticleLinkCollection
# EcalBarrelRelationsSimDigi               2639401739      edm4hep::CaloHitSimCaloHitLinkCollection
# EcalBarrelRelationsSimRec                3746919593      edm4hep::CaloHitSimCaloHitLinkCollection
# EcalEndcapRingRelationsSimDigi           2480939121      edm4hep::CaloHitSimCaloHitLinkCollection
# EcalEndcapRingRelationsSimRec            1930145151      edm4hep::CaloHitSimCaloHitLinkCollection
# EcalEndcapsRelationsSimDigi              2989754106      edm4hep::CaloHitSimCaloHitLinkCollection
# EcalEndcapsRelationsSimRec               439590450       edm4hep::CaloHitSimCaloHitLinkCollection
# FTDPixelTrackerHitRelations              2431389277      edm4hep::TrackerHitSimTrackerHitLinkCollection
# FTDSpacePointRelations                   249458290       edm4hep::TrackerHitSimTrackerHitLinkCollection
# FTDStripTrackerHitRelations              2269001718      edm4hep::TrackerHitSimTrackerHitLinkCollection
# HcalBarrelRelationsSimDigi               63049022        edm4hep::CaloHitSimCaloHitLinkCollection
# HcalBarrelRelationsSimRec                2708729306      edm4hep::CaloHitSimCaloHitLinkCollection
# HcalEndcapRingRelationsSimDigi           863975643       edm4hep::CaloHitSimCaloHitLinkCollection
# HcalEndcapRingRelationsSimRec            2503516356      edm4hep::CaloHitSimCaloHitLinkCollection
# HcalEndcapsRelationsSimDigi              3625828141      edm4hep::CaloHitSimCaloHitLinkCollection
# HcalEndcapsRelationsSimRec               2389117934      edm4hep::CaloHitSimCaloHitLinkCollection
# MCTruthClusterLink                       276380965       edm4hep::ClusterMCParticleLinkCollection
# MCTruthMarlinTrkTracksLink               662205816       edm4hep::TrackMCParticleLinkCollection
# MCTruthRecoLink                          3692307432      edm4hep::RecoMCParticleLinkCollection
# MarlinTrkTracksKaonMCP                   3506783534      edm4hep::TrackMCParticleLinkCollection
# MarlinTrkTracksMCTruthLink               2121937999      edm4hep::TrackMCParticleLinkCollection
# MarlinTrkTracksProtonMCP                 82368888        edm4hep::TrackMCParticleLinkCollection
# RecoMCTruthLink                          1803649914      edm4hep::RecoMCParticleLinkCollection
# RelationBCalHit                          383454308       edm4hep::CaloHitSimCaloHitLinkCollection
# RelationLHcalHit                         2162766563      edm4hep::CaloHitSimCaloHitLinkCollection
# RelationLcalHit                          945642295       edm4hep::CaloHitSimCaloHitLinkCollection
# RelationMuonHit                          3743703642      edm4hep::CaloHitSimCaloHitLinkCollection
# SETSpacePointRelations                   3439026726      edm4hep::TrackerHitSimTrackerHitLinkCollection
# SETTrackerHitRelations                   1857963609      edm4hep::TrackerHitSimTrackerHitLinkCollection
# SITTrackerHitRelations                   3692167069      edm4hep::TrackerHitSimTrackerHitLinkCollection
# TPCTrackerHitRelations                   4021612839      edm4hep::TrackerHitSimTrackerHitLinkCollection
# VXDTrackerHitRelations                   395088688       edm4hep::TrackerHitSimTrackerHitLinkCollection
